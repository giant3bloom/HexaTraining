# %%
employee_data = [
    (101, "Rahul", "IT", 75000),
    (102, "Priya", "HR", 65000),
    (103, "Arjun", "Finance", 80000),
    (104, "Sneha", "IT", 72000),
    (105, "Kiran", "Marketing", 60000)
]

columns = ["emp_id", "name", "department", "salary"]

# %%
employee_df = spark.createDataFrame(employee_data, columns)
employee_df.show()
print('employee load completed.')
# Out:
# +------+-----+----------+------+
# |emp_id| name|department|salary|
# +------+-----+----------+------+
# |   101|Rahul|        IT| 75000|
# |   102|Priya|        HR| 65000|
# |   103|Arjun|   Finance| 80000|
# |   104|Sneha|        IT| 72000|
# |   105|Kiran| Marketing| 60000|
# +------+-----+----------+------+

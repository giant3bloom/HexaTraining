# %%
customer_data = [
    (101, "Rahul", "Hyderabad", "rahul@gmail.com"),
    (102, "Priya", "Chennai", "priya@gmail.com"),
    (103, "Arjun", "Bangalore", "arjun@gmail.com"),
    (104, "Sneha", "Mumbai", "sneha@gmail.com"),
    (105, "Kiran", "Delhi", "kiran@gmail.com")
]

columns = ["customer_id", "customer_name", "city", "email"]

customer_df = spark.createDataFrame(customer_data, columns)
customer_df.show()

# %%
customer_df.write.mode('overwrite').saveAsTable('customer_table')
